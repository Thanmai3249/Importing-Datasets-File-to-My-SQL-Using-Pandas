# %%
from sqlalchemy import create_engine

import pymysql

import pandas as pd
# Credentials to database connection
hostname="localhost"
dbname="Superstore"
uname="root"
pwd="thanmai123"

# create dataframe from csv file
Fitbit= pd.read_csv("C:/Users/Thanmai/INEURON//FitBit data.csv")

# Create SQLAlchemy engine to connect to MySQL Database
engine = create_engine('mysql+pymysql://root:thanmai123@localhost:3306/Superstore'
        .format(host='localhost', database='Superstore', user='root', password='thanmai123'))


# Convert dataframe to sql table                                   
Fitbit.to_sql('Fitbit', engine, index=False)

Fitbit = pd.read_sql_query("SELECT * FROM Fitbit", engine)
Fitbit.head()
# Out:
# C:\Users\Thanmai\anaconda3\lib\site-packages\pandas\io\sql.py:1663: UserWarning: The provided table name 'Fitbit' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# ...
